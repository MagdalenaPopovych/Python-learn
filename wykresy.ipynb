# %%
import klubplywacki
fn = "Darek-13-100m-motyl.txt"
(swimmer, age, distance, stroke, *_) = klubplywacki.read_swim_data(fn)
title = swimmer + " (poniżej " + age + " lat), " + distance + ", styl: " + stroke

# %%
title
# Out:
# 'Darek (poniżej 13 lat), 100m, styl: motyl'

# %%
html = "<!DOCTYPE html><html><head><title>" + title
html = html + "</title></head><body><h3>" + title + "</h3>"
html
# Out:
# '<!DOCTYPE html><html><head><title>Darek (poniżej 13 lat), 100m, styl: motyl</title></head><body><h3>Darek (poniżej 13 lat), 100m, styl: motyl</h3>'

# %%
title = f"{swimmer} (poniżej {age} lat), {distance}, styl: {stroke}"

# %%
html = f"""<!DOCTYPE html>
<html>
    <head>
        <title>{title}</title>
    </head>
    <body>
        <h3>{title}</h3>"""

# %%
title
# Out:
# 'Darek (poniżej 13 lat), 100m, styl: motyl'

# %%
html
# Out:
# '<!DOCTYPE html>\n<html>\n    <head>\n        <title>Darek (poniżej 13 lat), 100m, styl: motyl</title>\n    </head>\n    <body>\n        <h3>Darek (poniżej 13 lat), 100m, styl: motyl</h3>'

# %%
print(html)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Darek (poniżej 13 lat), 100m, styl: motyl</title>
#     </head>
#     <body>
#         <h3>Darek (poniżej 13 lat), 100m, styl: motyl</h3>

# %%
fn
# Out:
# 'Darek-13-100m-motyl.txt'

# %%
fn = "Darek-13-100m-motyl.txt"
klubplywacki.read_swim_data(fn)
# Out:
# ('Darek',
#  '13',
#  '100m',
#  'motyl',
#  ['1:27,95', '1:21,07', '1:30,96', '1:23,22', '1:27,95', '1:28,30'],
#  '1:26,58',
#  [8795, 8107, 9096, 8322, 8795, 8830])

# %%
svgs = svgs + f"""
        <svg height="30" width="400">
            <rect height="30" width="{bar_width}" style="fill:rgb(0,0,255);" />
        </svg>{t}<br />"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 svgs = svgs + f"""
#       2         <svg height="30" width="400">
# ----> 3             <rect height="30" width="{bar_width}" style="fill:rgb(0,0,255);" />
#       4         </svg>{t}<br />"""
#
# NameError: name 'bar_width' is not defined

# %%
bar_width = pyrg_funkcje.convert2range(converts[n], 0, from_max, 0, 400)
for n, t in enumerate(times):
# Out:
#   Cell In[18], line 2
#     for n, t in enumerate(times):
#     ^
# IndentationError: unexpected indent

# %%
*_, times, avarage, converts = klubplywacki.read_swim_data(fn)
from_max = max(converts)
svgs = ""
for n, t in enumerate(times):
    bar_width = pyrg_funkcje.convert2range(converts[n], 0, from_max, 0, 400)
    svgs = svgs + f"""
        <svg height="30" width="400">
            <rect height="30" width="{bar_width}" style="fill:rgb(0,0,255);" />
        </svg>{t}<br />
    """

# %%
print(svgs)
# Out:
#         <svg height="30" width="400">
#             <rect height="30" width="386.76" style="fill:rgb(0,0,255);" />
#         </svg>1:27,95<br />
#
#         <svg height="30" width="400">
#             <rect height="30" width="356.51" style="fill:rgb(0,0,255);" />
#         </svg>1:21,07<br />
#
#         <svg height="30" width="400">
#             <rect height="30" width="400.0" style="fill:rgb(0,0,255);" />
#         </svg>1:30,96<br />
#
#         <svg height="30" width="400">
#             <rect height="30" width="365.96" style="fill:rgb(0,0,255);" />
#         </svg>1:23,22<br />
#
#         <svg height="30" width="400">
#             <rect height="30" width="386.76" style="fill:rgb(0,0,255);" />
#         </svg>1:27,95<br />
#
#         <svg height="30" width="400">
#             <rect height="30" width="388.3" style="fill:rgb(0,0,255);" />
#         </svg>1:28,30<br />

# %%
footer = f"""
        <p>Średni czas: {avarage}</p>
    </body>
</html>
"""

# %%
page = html + svgs + footer
