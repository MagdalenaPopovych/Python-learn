# %%
import klubplywacki

# %%
klubplywacki.read_swim_data("Darek-13-100m-motyl.txt")
# Out:
# ('Darek',
#  '13',
#  '100m',
#  'motyl',
#  ['1:27,95', '1:21,07', '1:30,96', '1:23,22', '1:27,95', '1:28,30'],
#  '1:26,58')

# %%
data = klubplywacki.read_swim_data("Darek-13-100m-motyl.txt")

# %%
times = data[4]

# %%
times
# Out:
# ['1:27,95', '1:21,07', '1:30,96', '1:23,22', '1:27,95', '1:28,30']

# %%
swimmer, age, distance, stroke, times2, avarage = data

# %%
times2
# Out:
# ['1:27,95', '1:21,07', '1:30,96', '1:23,22', '1:27,95', '1:28,30']

# %%
data
# Out:
# ('Darek',
#  '13',
#  '100m',
#  'motyl',
#  ['1:27,95', '1:21,07', '1:30,96', '1:23,22', '1:27,95', '1:28,30'],
#  '1:26,58')

# %%
times = data[4]
times
# Out:
# ['1:27,95', '1:21,07', '1:30,96', '1:23,22', '1:27,95', '1:28,30']

# %%
swimmer, age, distance, stroke, times2, avarage = data
times2
# Out:
# ['1:27,95', '1:21,07', '1:30,96', '1:23,22', '1:27,95', '1:28,30']

# %%
import os

# %%
swim_files = os.listdir(klubplywacki.FOLDER)

# %%
len(swim_files)
# Out:
# 61

# %%
print(swim_files)
# Out:
# ['.DS_Store', 'Ala-12-100m-grzbietowy.txt', 'Ala-12-100m-kraul.txt', 'Alicja-14-100m-klasyczny.txt', 'Alicja-14-100m-kraul.txt', 'Ania-10-100m-grzbietowy.txt', 'Ania-10-100m-klasyczny.txt', 'Ania-10-50m-grzbietowy.txt', 'Ania-10-50m-klasyczny.txt', 'Ania-10-50m-kraul.txt', 'Aurora-13-50m-kraul.txt', 'Bartek-18-100m-grzbietowy.txt', 'Bartek-18-200m-grzbietowy.txt', 'Benek-15-100m-grzbietowy.txt', 'Benek-15-100m-kraul.txt', 'Benek-15-100m-motyl.txt', 'Darek-13-100m-grzbietowy.txt', 'Darek-13-100m-klasyczny.txt', 'Darek-13-100m-motyl.txt', 'Darek-13-200m-zmienny.txt', 'Dawid-17-100m-kraul.txt', 'Dawid-17-200m-grzbietowy.txt', 'Ela-14-100m-kraul.txt', 'Eliza-14-100m-grzbietowy.txt', 'Eliza-14-100m-kraul.txt', 'Emma-13-100m-klasyczny.txt', 'Emma-13-100m-kraul.txt', 'Eryka-15-100m-klasyczny.txt', 'Eryka-15-100m-kraul.txt', 'Eryka-15-200m-klasyczny.txt', 'Hanna-13-100m-grzbietowy.txt', 'Hanna-13-100m-kraul.txt', 'Karol-15-100m-grzbietowy.txt', 'Kasia-9-100m-grzbietowy.txt', 'Kasia-9-100m-kl
# ...

# %%
print(dir(swim_files))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
print(sorted(swim_files))
# Out:
# ['.DS_Store', 'Ala-12-100m-grzbietowy.txt', 'Ala-12-100m-kraul.txt', 'Alicja-14-100m-klasyczny.txt', 'Alicja-14-100m-kraul.txt', 'Ania-10-100m-grzbietowy.txt', 'Ania-10-100m-klasyczny.txt', 'Ania-10-50m-grzbietowy.txt', 'Ania-10-50m-klasyczny.txt', 'Ania-10-50m-kraul.txt', 'Aurora-13-50m-kraul.txt', 'Bartek-18-100m-grzbietowy.txt', 'Bartek-18-200m-grzbietowy.txt', 'Benek-15-100m-grzbietowy.txt', 'Benek-15-100m-kraul.txt', 'Benek-15-100m-motyl.txt', 'Darek-13-100m-grzbietowy.txt', 'Darek-13-100m-klasyczny.txt', 'Darek-13-100m-motyl.txt', 'Darek-13-200m-zmienny.txt', 'Dawid-17-100m-kraul.txt', 'Dawid-17-200m-grzbietowy.txt', 'Ela-14-100m-kraul.txt', 'Eliza-14-100m-grzbietowy.txt', 'Eliza-14-100m-kraul.txt', 'Emma-13-100m-klasyczny.txt', 'Emma-13-100m-kraul.txt', 'Eryka-15-100m-klasyczny.txt', 'Eryka-15-100m-kraul.txt', 'Eryka-15-200m-klasyczny.txt', 'Hanna-13-100m-grzbietowy.txt', 'Hanna-13-100m-kraul.txt', 'Karol-15-100m-grzbietowy.txt', 'Kasia-9-100m-grzbietowy.txt', 'Kasia-9-100m-kl
# ...

# %%
help(list.clear)
# Out:
# Help on method_descriptor:
#
# clear(self, /) unbound builtins.list method
#     Remove all items from list.

# %%
help(list.copy)
# Out:
# Help on method_descriptor:
#
# copy(self, /) unbound builtins.list method
#     Return a shallow copy of the list.

# %%
help(list.count)
# Out:
# Help on method_descriptor:
#
# count(self, value, /) unbound builtins.list method
#     Return number of occurrences of value.

# %%
help(list.extend)
# Out:
# Help on method_descriptor:
#
# extend(self, iterable, /) unbound builtins.list method
#     Extend list by appending elements from the iterable.

# %%
help(list.index)
# Out:
# Help on method_descriptor:
#
# index(self, value, start=0, stop=9223372036854775807, /) unbound builtins.list method
#     Return first index of value.
#
#     Raises ValueError if the value is not present.

# %%
help(set.add)
# Out:
# Help on method_descriptor:
#
# add(self, object, /) unbound builtins.set method
#     Add an element to a set.
#
#     This has no effect if the element is already present.

# %%
help(list.remove)
# Out:
# Help on method_descriptor:
#
# remove(self, value, /) unbound builtins.list method
#     Remove first occurrence of value.
#
#     Raises ValueError if the value is not present.

# %%
help(swim_files.remove)
# Out:
# Help on built-in function remove:
#
# remove(value, /) method of builtins.list instance
#     Remove first occurrence of value.
#
#     Raises ValueError if the value is not present.

# %%
swim_files.remove(".DS_Store")

# %%
len(swim_files)
# Out:
# 60

# %%
for t in times:
    print(t)
# Out:
# 1:27,95
# 1:21,07
# 1:30,96
# 1:23,22
# 1:27,95
# 1:28,30

# %%
for s in swim_files:
    print("Przetwarzanie pliku: ", s)
klubplywacki.read_swim_data(s)
# Out:
# Przetwarzanie pliku:  Ala-12-100m-grzbietowy.txt
# Przetwarzanie pliku:  Ala-12-100m-kraul.txt
# Przetwarzanie pliku:  Alicja-14-100m-klasyczny.txt
# Przetwarzanie pliku:  Alicja-14-100m-kraul.txt
# Przetwarzanie pliku:  Ania-10-100m-grzbietowy.txt
# Przetwarzanie pliku:  Ania-10-100m-klasyczny.txt
# Przetwarzanie pliku:  Ania-10-50m-grzbietowy.txt
# Przetwarzanie pliku:  Ania-10-50m-klasyczny.txt
# Przetwarzanie pliku:  Ania-10-50m-kraul.txt
# Przetwarzanie pliku:  Aurora-13-50m-kraul.txt
# Przetwarzanie pliku:  Bartek-18-100m-grzbietowy.txt
# Przetwarzanie pliku:  Bartek-18-200m-grzbietowy.txt
# Przetwarzanie pliku:  Benek-15-100m-grzbietowy.txt
# Przetwarzanie pliku:  Benek-15-100m-kraul.txt
# Przetwarzanie pliku:  Benek-15-100m-motyl.txt
# Przetwarzanie pliku:  Darek-13-100m-grzbietowy.txt
# Przetwarzanie pliku:  Darek-13-100m-klasyczny.txt
# Przetwarzanie pliku:  Darek-13-100m-motyl.txt
# Przetwarzanie pliku:  Darek-13-200m-zmienny.txt
# ...

# %%
for n, s in enumerate(swim_files, 1):
    print(n, "Przetwarzanie pliku: ", s)
klubplywacki.read_swim_data(s)
# Out:
# 1 Przetwarzanie pliku:  Ala-12-100m-grzbietowy.txt
# 2 Przetwarzanie pliku:  Ala-12-100m-kraul.txt
# 3 Przetwarzanie pliku:  Alicja-14-100m-klasyczny.txt
# 4 Przetwarzanie pliku:  Alicja-14-100m-kraul.txt
# 5 Przetwarzanie pliku:  Ania-10-100m-grzbietowy.txt
# 6 Przetwarzanie pliku:  Ania-10-100m-klasyczny.txt
# 7 Przetwarzanie pliku:  Ania-10-50m-grzbietowy.txt
# 8 Przetwarzanie pliku:  Ania-10-50m-klasyczny.txt
# 9 Przetwarzanie pliku:  Ania-10-50m-kraul.txt
# 10 Przetwarzanie pliku:  Aurora-13-50m-kraul.txt
# 11 Przetwarzanie pliku:  Bartek-18-100m-grzbietowy.txt
# 12 Przetwarzanie pliku:  Bartek-18-200m-grzbietowy.txt
# 13 Przetwarzanie pliku:  Benek-15-100m-grzbietowy.txt
# 14 Przetwarzanie pliku:  Benek-15-100m-kraul.txt
# 15 Przetwarzanie pliku:  Benek-15-100m-motyl.txt
# 16 Przetwarzanie pliku:  Darek-13-100m-grzbietowy.txt
# 17 Przetwarzanie pliku:  Darek-13-100m-klasyczny.txt
# 18 Przetwarzanie pliku:  Darek-13-100m-motyl.txt
# ...
